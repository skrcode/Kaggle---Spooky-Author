# %%
import data_read 
import data_clean
import train_fasttext
import vector_avg
import get_sentences
import centroid_bow
import train
import run_test
import write_result

# %%
reload(data_read)
X_train,X_test = data_read.do()

# %%
reload(data_clean)
w1,w2,w3,w4 = data_clean.do()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-17-3121aad6bac6> in <module>()
#       1 reload(data_clean)
# ----> 2 content = data_clean.do(X_train)
#
# /Users/16521/Kaggle/Quora_Question_Pairs/src/data_clean.pyc in do(X_train)
#      49
#      50 def do(X_train):
# ---> 51         model = fasttext.load_model('../models/model.bin')
#      52         #get_corpus(X_train)
#      53         #remove()
#
# fasttext/fasttext.pyx in fasttext.fasttext.load_model (fasttext/fasttext.cpp:3891)()
#
# Exception: fastText: Cannot load ../models/model.bin due to C++ extension failed to allocate the memory

# %%
result = (wv1-wv2)*(wv1-wv2)

# %%
net_result = pd.concat([result, X_train['is_duplicate']], axis=1,ignore_index=True)

# %%
result_test = (wv1-wv2)*(wv1-wv2)

# %%
result_test = result_test.drop(result_test.index[len(result_test)-1])

# %%
result.isnull().any().any()
# Out:
# False

# %%
result_test
# Out:
#                    0             1         2         3             4   \
# 0        6.563430e-03  6.937956e-04  0.000126  0.000002  7.459563e-04
# 1        1.675019e-03  4.028049e-04  0.001064  0.000166  3.157316e-05
# 2        5.832708e-04  1.338649e-04  0.004511  0.001773  6.004950e-04
# 3        4.173160e-05  1.015888e-03  0.000052  0.000214  1.000400e-02
# 4        1.518193e-03  1.038966e-03  0.000530  0.000023  6.859964e-03
# 5        2.277081e-04  2.566404e-04  0.000012  0.000240  2.806668e-03
# 6        4.181207e-04  2.970250e-05  0.000024  0.000029  2.709974e-04
# 7        1.231547e-03  8.132763e-04  0.001097  0.000053  4.215630e-04
# 8        3.038214e-05  1.016064e-04  0.000318  0.000002  8.832784e-06
# 9        8.248958e-04  1.183360e-05  0.001219  0.000306  9.341581e-04
# 10       5.473588e-04  7.903210e-05  0.000013  0.000002  6.950078e-04
# 11       1.475010e-06  1.090320e-03  0.000040  0.000216  1.023168e-03
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# Fit a random forest and extract predictions 
forest = RandomForestClassifier(n_estimators = 700,min_samples_leaf=3,n_jobs=-1)

# Fitting the forest may take a few minutes
print "Fitting a random forest to labeled training data..."
forest = forest.fit(result, X_train['is_duplicate'])
# Out:
# Fitting a random forest to labeled training data...
# ---------------------------------------------------------------------------
# JoblibValueError                          Traceback (most recent call last)
# <ipython-input-135-7f48c78ca524> in <module>()
#       6 # Fitting the forest may take a few minutes
#       7 print "Fitting a random forest to labeled training data..."
# ----> 8 forest = forest.fit(result, X_train['is_duplicate'])
#       9
#
# /Users/16521/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in fit(self, X, y, sample_weight)
#     271                     t, self, X, y, sample_weight, i, len(trees),
#     272                     verbose=self.verbose, class_weight=self.class_weight)
# --> 273                 for i, t in enumerate(trees))
#     274
#     275             # Collect newly grown trees
#
# /Users/16521/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
# ...

# %%
reload(train_fasttext)
mode = train_fasttext.do()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-9bc242ce9576> in <module>()
#       1 reload(train_fasttext)
# ----> 2 mode = train_fasttext.do()
#
# /Users/16521/Kaggle/Quora_Question_Pairs/src/train_fasttext.pyc in do()
#       3 def do():
#       4         # Skipgram model
# ----> 5         model = fasttext.skipgram('../data/sentences_replace', 'model')
#       6         return model
#       7
#
# fasttext/fasttext.pyx in fasttext.fasttext.skipgram (fasttext/fasttext.cpp:5886)()
#
# fasttext/fasttext.pyx in fasttext.fasttext.train_wrapper (fasttext/fasttext.cpp:4770)()
#
# ValueError: fastText: cannot load ../data/sentences_replace

# %%
X_train.loc[1,"question2"]
# Out:
# 'What would happen if the Indian government stole the Kohinoor (Koh-i-Noor) diamond back?'

# %%
reload(run_test)
result = run_test.do()

# %%
reload(write_result)

write_result.do(result,X_test)

# %%
reload(train_fasttext)
model = train_fasttext.do(X_train)
# Out:
# Training model...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-ba77f550c677> in <module>()
#       1 reload(train_fasttext)
# ----> 2 model = train_fasttext.do(X_train)
#
# /Users/16521/Kaggle/Quora_Question_Pairs/src/train_fasttext.pyc in do(X_train)
#      17         from gensim.models import word2vec
#      18         print "Training model..."
# ---> 19 	model = word2vec.Word2Vec(train_sentences, workers=num_workers, \
#      20                     min_count = min_word_count, \
#      21 	            window = context, sample = downsampling)
#
# NameError: global name 'train_sentences' is not defined

# %%
reload(get_sentences)
train_sentences,test_sentences = get_sentences.do(X_train['review'],X_test['review'])
# Out:
# Parsing sentences from test set
# /Users/16521/anaconda/lib/python2.7/site-packages/bs4/__init__.py:207: UserWarning: "https://m.facebook.com/nitsrinagarcrisis2016/" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.
#   '"%s" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client to get the document behind the URL, and feed that document to Beautiful Soup.' % markup)
# /Users/16521/anaconda/lib/python2.7/site-packages/bs4/__init__.py:198: UserWarning: ".." looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   '"%s" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.' % markup)
# ...

# %%
reload(train_word2vec)
model = train_word2vec.do(train_sentences)
# Out:
# Training model...
# Training complete..!!

# %%
reload(centroid_bow)
train_centroids,test_centroids = centroid_bow.do(model,X_train,X_test)
# Out:
# Time taken for K Means clustering:  1.09363102913 seconds.

# %%
reload(train)
result = train.do(X_train,train_centroids,test_centroids)
# Out:
# Fitting a random forest to labeled training data...

# %%
reload(write_result)
write_result.do(result,X_test)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-a2fdb1dc4aa3> in <module>()
#       1 reload(write_result)
# ----> 2 write_result.do(result,X_train)
#
# /Users/16521/Desktop/Quora-Indian/src/write_result.pyc in do(result, test)
#       2 def do(result,test):
#       3         # Write the test results
# ----> 4         output = pd.DataFrame(data={"id":test["id"], "type":result})
#       5         output.to_csv( "result.csv", index=False, quoting=3 )
#
# /Users/16521/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1795             return self._getitem_multilevel(key)
#    1796         else:
# -> 1797             return self._getitem_column(key)
#    1798
#    1799     def _getitem_column(self, key):
#
# /Users/16521/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
# ...

# %%
import run_train
reload(run_train)
run_train

# %%
reset_selective train
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])?  y

# %%
reload(get_sentences)
train_sentences,test_sentences = get_sentences.do(X_train['review'],X_CV['review'])
reload(train_word2vec)
model = train_word2vec.do(train_sentences)
reload(centroid_bow)
train_centroids,test_centroids = centroid_bow.do(model,X_train,X_CV)
reload(train)
result = train.do(X_train,train_centroids,test_centroids)
# Out:
# Parsing sentences from test set
# Parsing sentences from train set
# Training model...
# Training complete..!!
# Time taken for K Means clustering:  0.715313911438 seconds.
# Fitting a random forest to labeled training data...

# %%
X_train = X_train.sample(frac=1).reset_index(drop=True)

# %%
X_CV = X_train[2500::]
X_train = X_train[0:2500]

# %%
import numpy as np
from sklearn.metrics import accuracy_score
accuracy_score(result,X_CV['type'] )
# Out:
# 0.97344228804902966

# %%
X_CV.shape
# Out:
# (979, 2)
